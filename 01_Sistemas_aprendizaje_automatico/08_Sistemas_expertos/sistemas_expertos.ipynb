# %%
# Importar librerías
from experta import *
import networkx as nx
import matplotlib.pyplot as plt

print("Entorno de sistemas expertos configurado")
print("Listo para crear sistemas basados en conocimiento")
