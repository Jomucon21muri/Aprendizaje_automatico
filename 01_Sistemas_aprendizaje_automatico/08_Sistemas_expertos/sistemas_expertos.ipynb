# %% [markdown]
# <a href="https://colab.research.google.com/github/Jomucon21muri/Aprendizaje_automatico/blob/main/01_Sistemas_aprendizaje_automatico/08_Sistemas_expertos/sistemas_expertos.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>
#
# # Sistemas expertos
#
# ## Introducción
#
# Bienvenido al notebook de **Sistemas expertos**. Construiremos sistemas basados en conocimiento para resolver problemas específicos de dominio.
#
# ### Temas que veremos:
#
# 1. **Arquitectura de sistemas expertos**
#    - Base de conocimiento
#    - Motor de inferencia
#    - Interfaz de usuario
#    - Módulo de explicación
#
# 2. **Representación del conocimiento**
#    - Reglas de producción (Si-Entonces)
#    - Frames y redes semánticas
#    - Lógica de predicados
#    - Ontologías
#
# 3. **Métodos de inferencia**
#    - Encadenamiento hacia adelante (forward chaining)
#    - Encadenamiento hacia atrás (backward chaining)
#    - Resolución de conflictos
#
# 4. **Implementación práctica**
#    - Sistema experto de diagnóstico médico
#    - Sistema de recomendación
#    - Sistema de planificación
#
# 5. **Herramientas**
#    - CLIPS (C Language Integrated Production System)
#    - Experta (Python)
#    - Prolog
#
# ---
#
# **Aplicaciones:**
# - Diagnóstico médico
# - Configuración de sistemas
# - Asesoramiento financiero
#
# **Duración estimada:** 6-8 horas

# %%
# Importar librerías
from experta import *
import networkx as nx
import matplotlib.pyplot as plt

print("Entorno de sistemas expertos configurado")
print("Listo para crear sistemas basados en conocimiento")
