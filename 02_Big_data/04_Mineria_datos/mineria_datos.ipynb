# %% [markdown]
# <a href="https://colab.research.google.com/github/Jomucon21muri/Aprendizaje_automatico/blob/main/02_Big_data/04_Mineria_datos/mineria_datos.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>
#
# # Minería de datos
#
# ## Introducción
#
# Bienvenido al notebook de **Minería de datos**. Extraeremos conocimiento valioso de grandes conjuntos de datos usando la metodología CRISP-DM.
#
# ### Temas que veremos:
#
# 1. **Metodología CRISP-DM**
#    - Business understanding (comprensión del negocio)
#    - Data understanding (comprensión de los datos)
#    - Data preparation (preparación de datos)
#    - Modeling (modelado)
#    - Evaluation (evaluación)
#    - Deployment (despliegue)
#
# 2. **Técnicas de minería**
#    - Reglas de asociación (Apriori, FP-Growth)
#    - Market basket analysis
#    - Análisis secuencial
#    - Text mining
#
# 3. **Clustering a escala**
#    - K-means distribuido
#    - Bisecting K-means
#    - Gaussian mixture models
#    - Evaluación de clusters
#
# 4. **Clasificación distribuida**
#    - Decision trees (árboles de decisión)
#    - Random forest
#    - Gradient boosting
#    - Naive Bayes
#
# 5. **Feature selection**
#    - Chi-squared test
#    - Correlation analysis
#    - PCA distribuido
#
# 6. **Patrones frecuentes**
#    - Frequent pattern mining
#    - FP-Growth algorithm
#    - Sequential pattern mining
#
# ---
#
# **Librerías:**
# - PySpark MLlib
# - MLflow (tracking)
#
# **Duración estimada:** 10-12 horas

# %%
# Importar librerías
from pyspark.sql import SparkSession
from pyspark.ml.clustering import KMeans, BisectingKMeans
from pyspark.ml.classification import RandomForestClassifier, GBTClassifier
from pyspark.ml.fpm import FPGrowth
from pyspark.ml.feature import VectorAssembler, StandardScaler
from pyspark.ml import Pipeline

# Crear sesión
spark = SparkSession.builder \
    .appName("MineriaDatos") \
    .master("local[*]") \
    .getOrCreate()

print("Entorno de minería de datos configurado")
print("Listo para aplicar CRISP-DM y técnicas de minería")
