# %% [markdown]
# <a href="https://colab.research.google.com/github/Jomucon21muri/Aprendizaje_automatico/blob/main/02_Big_data/01_Fundamentos_big_data/fundamentos_big_data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>
#
# # Fundamentos big data
#
# ## Introducción
#
# Bienvenido al notebook de **Fundamentos de big data**. Aprenderemos los conceptos esenciales para trabajar con datos a gran escala.
#
# ### Temas que veremos:
#
# 1. **Las 5 V del big data**
#    - Volumen: escala de datos
#    - Velocidad: velocidad de generación
#    - Variedad: tipos de datos (estructurados, no estructurados)
#    - Veracidad: calidad y confiabilidad
#    - Valor: extracción de insights
#
# 2. **Arquitecturas de big data**
#    - Sistemas distribuidos
#    - Arquitectura lambda
#    - Arquitectura kappa
#    - Data lakes vs data warehouses
#
# 3. **Ecosistema Hadoop**
#    - HDFS (Hadoop distributed file system)
#    - MapReduce
#    - YARN (yet another resource negotiator)
#    - Hive, Pig, HBase
#
# 4. **Almacenamiento distribuido**
#    - Sistemas de archivos distribuidos
#    - Bases de datos NoSQL
#    - Object storage
#
# 5. **Casos de uso**
#    - Análisis en tiempo real
#    - Procesamiento batch
#    - Machine learning a escala
#
# ---
#
# **Tecnologías:**
# - Hadoop
# - HDFS
# - Cloud platforms (AWS, Azure, GCP)
#
# **Duración estimada:** 6-8 horas

# %%
# Importar librerías
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

print("Entorno configurado para fundamentos de big data")
print("Listo para explorar conceptos de datos a gran escala")
