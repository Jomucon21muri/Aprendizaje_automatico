# %% [markdown]
# # 📊 Fundamentos de Big Data
# ## Infraestructuras y Paradigmas de Procesamiento Masivo
#
# <a href="https://colab.research.google.com/github/Jomucon21muri/Aprendizaje_automatico/blob/main/02_Big_data/01_Fundamentos_big_data/fundamentos_big_data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>
#
# ---
#
# ## 📋 Resumen
#
# Big Data se refiere al procesamiento y análisis de conjuntos de datos masivos que exceden las capacidades de herramientas tradicionales.
#
# ### 🎯 Las 5 V's de Big Data
#
# 1. **Volumen**: Terabytes, Petabytes, Exabytes de datos
# 2. **Velocidad**: Generación y procesamiento en tiempo real
# 3. **Variedad**: Datos estructurados, semi-estructurados, no estructurados
# 4. **Veracidad**: Calidad, confiabilidad de los datos
# 5. **Valor**: Extracción de insights accionables
#
# ### 🏗️ Arquitecturas
#
# **Tradicional (Vertical Scaling)**:
# - Aumentar recursos de un único servidor
# - Limitaciones físicas y costos exponenciales
#
# **Big Data (Horizontal Scaling)**:
# - Distribuir carga entre múltiples nodos
# - Escalabilidad prácticamente ilimitada
#
# ### 🛠️ Tecnologías Clave
#
# | Tecnología | Propósito | Ejemplo |
# |------------|-----------|---------|
# | **Hadoop** | Framework distribuido | HDFS, MapReduce |
# | **Spark** | Procesamiento in-memory | PySpark |
# | **NoSQL** | Bases de datos escalables | MongoDB, Cassandra |
# | **Streaming** | Tiempo real | Kafka, Flink |
# | **Cloud** | Infraestructura | AWS, GCP, Azure |
#
# ---

# %%
# Setup Big Data
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

print("✅ Fundamentos Big Data")
print("\n📊 Características:")
print("  • Volumen: Datasets masivos (TB, PB)")
print("  • Velocidad: Generación/procesamiento rápido")
print("  • Variedad: Múltiples formatos y fuentes")
print("  • Veracidad: Calidad y confiabilidad")
print("  • Valor: Insights accionables")
print("\n🛠️ Ecosistema Hadoop:")
print("  • HDFS: Distributed File System")
print("  • MapReduce: Procesamiento distribuido")
print("  • YARN: Resource manager")
print("  • Hive, Pig, HBase: Herramientas adicionales")
print("\n⚡ Apache Spark:")
print("  • 100x más rápido que MapReduce")
print("  • Procesamiento in-memory")
print("  • APIs: Scala, Python (PySpark), Java, R")
print("\n📖 Recursos:")
print("  • Apache Hadoop: https://hadoop.apache.org")
print("  • Apache Spark: https://spark.apache.org")
